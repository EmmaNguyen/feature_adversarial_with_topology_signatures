# %%
import numpy as np
import gs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Let us generate a simple circluar dataset

x = gs.circle()

# %%
plt.scatter(x[:, 0], x[:, 1], s=0.1)

# %%
#Input data is an coordination of 5000 2-d points in a plan
#Each point is an observation
x.shape
# Out:
# (5000, 2)

# %%
# Compute RLT (just 100 samples for speed)

rltx = gs.rlts(x, n=100, L_0=32, i_max=10, gamma=1.0/8)
# Out:
# Done 0/100
# Done 10/100
# Done 20/100
# Done 30/100
# Done 40/100
# Done 50/100
# Done 60/100
# Done 70/100
# Done 80/100
# Done 90/100

# %%
mrltx = np.mean(rltx, axis=0)

# %%
gs.fancy_plot(mrltx[:3])
plt.xticks(np.arange(3));

# %%
# Get a second dataset for comparison...

y = gs.filled_circle()

# %%
plt.scatter(y[:, 0], y[:, 1], s=0.1)

# %%
rlty = gs.rlts(y, n=100, L_0=32, i_max=10, gamma=1.0/8)
# Out:
# Done 0/100
# Done 10/100
# Done 20/100
# Done 30/100
# Done 40/100
# Done 50/100
# Done 60/100
# Done 70/100
# Done 80/100
# Done 90/100

# %%
mrlty = np.mean(rlty, axis=0)

# %%
gs.fancy_plot(mrlty[:3])
plt.xticks(np.arange(3));

# %%
# Compute score
gs.geom_score(rltx, rlty)
# Out:
# 1.8448901940212625
